# %% [markdown]
# Analisi dei dati COVID, iniziamo importando le librerie che andremo ad usare:

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

dati = pd.read_csv('covid.csv')
dati
# Out:
#                       data stato  codice_regione denominazione_regione  \
# 0      2020-02-24T18:00:00   ITA              13               Abruzzo
# 1      2020-02-24T18:00:00   ITA              17            Basilicata
# 2      2020-02-24T18:00:00   ITA              18              Calabria
# 3      2020-02-24T18:00:00   ITA              15              Campania
# 4      2020-02-24T18:00:00   ITA               8        Emilia-Romagna
# ...                    ...   ...             ...                   ...
# 28135  2023-10-25T17:00:00   ITA              19               Sicilia
# 28136  2023-10-25T17:00:00   ITA               9               Toscana
# 28137  2023-10-25T17:00:00   ITA              10                Umbria
# 28138  2023-10-25T17:00:00   ITA               2         Valle d'Aosta
# 28139  2023-10-25T17:00:00   ITA               5                Veneto
#
#              lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# ...

# %% [markdown]
# Filtriamo i dati del FVG e ne facciamo il grafico.

# %%
FVG = dati[dati["denominazione_regione"] == "Friuli Venezia Giulia"][["data","ricoverati_con_sintomi","terapia_intensiva","deceduti"]]
FVG
# Out:
#                       data  ricoverati_con_sintomi  terapia_intensiva
# 5      2020-02-24T18:00:00                       0                  0
# 26     2020-02-25T18:00:00                       0                  0
# 47     2020-02-26T18:00:00                       0                  0
# 68     2020-02-27T18:00:00                       0                  0
# 89     2020-02-28T18:00:00                       0                  0
# ...                    ...                     ...                ...
# 28040  2023-10-21T17:00:00                     126                  2
# 28061  2023-10-22T17:00:00                     128                  2
# 28082  2023-10-23T17:00:00                     138                  2
# 28103  2023-10-24T17:00:00                     131                  2
# 28124  2023-10-25T17:00:00                     123                  3
#
# [1340 rows x 3 columns]

# %% [markdown]
# Adesso proviamo a graficare i dati

# %%
fig, ax = plt.subplots(1,1, figsize=(14, 8), layout='constrained')

FVG.plot(x="data", y ="ricoverati_con_sintomi", ax=ax)
FVG.plot(x="data", y ="terapia_intensiva", ax=ax)
# Out:
# <Axes: xlabel='data'>
